# %%
import pandas as pd

df = pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                             Heikkinen, Miss. Laina  female  26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                           Allen, Mr. William Henry    male  35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  Null        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  Null        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500  Null        S

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    object
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000    8.000000    6.000000  512.329200

# %%
df.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                      Sex     Age   SibSp  Parch  Ticket      Fare    Cabin  Embarked
# 1            0         3       Braund, Mr. Owen Harris                   male    22    1      0      A/5 21171   7.250   Null   S           1
# 599          0         3       Boulos, Mr. Hanna                         male    Null  0      0      2664        7.225   Null   C           1
# 588          1         1       Frolicher-Stehli, Mr. Maxmillian          male    60    1      1      13567       79.200  B41    C           1
# 589          0         3       Gilinski, Mr. Eliezer                     male    22    0      0      14973       8.050   Null   S           1
# 590          0         3       Murdlin, Mr. Joseph                       male    Null  0      0      A./5. 3235  8.050   Null   S           1
#                                                                                                                                            ..
# 301          1         3       Kelly, Miss. Anna Katherine "Annie Kate"  female  Null  0      0      9234        7.750   Null   Q           1
# 302          1         3       McCoy, Mr. Bernard                        male    Null  2      0      367226      23.250  Null   Q           1
# 303          0         3       Johnson, Mr. William Cahoone Jr           male    19    0      0      LINE        0.000   Null   S           1
# 304          1         2       Keane, Miss. Nora A                       female  Null  0      0      226593      12.350  E101   Q           1
# 891          0         3       Dooley, Mr. Patrick                       male    32    0      0      370376      7.750   Null   Q           1
# Name: count, Length: 891, dtype: int64

# %%
df.isnull().sum()
df.duplicated().sum()
# Out:
# 0

# %%
df.hist(figsize=(10,8), bins=20)
plt.show()

# %%
import seaborn as sns
sns.boxplot(x=df['Fare'])
plt.show()

# %%
sns.countplot(data=df, x='Survived')
plt.show()

# %%
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.show()
# Out:
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# First, select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate correlation matrix
corr = numeric_df.corr()

# Create heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()
